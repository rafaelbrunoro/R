# %% [markdown]
# # Trabalho final - Python para Data Science

# %%
import numpy as np
import pandas as pd

# %%
# Leitura de dataset através de arquivo xlsx
xlsx = pd.read_excel('dataset-cpid.xlsx','data')
xlsx
# Out:
#          Horas   snr  Potencia medida(dBm)  Potencia Simulada-76%(dBm)  \
# 0     16:12:19  10.0                   -75                       -64.1
# 1     09:12:21   8.2                   -64                       -61.7
# 2     09:12:16   9.2                   -55                       -61.8
# 3     09:12:11   9.5                   -59                       -63.0
# 4     09:11:59  11.5                   -62                       -62.7
# ...        ...   ...                   ...                         ...
# 1569  15:14:44   8.8                   -86                      -101.9
# 1570  15:15:57   3.0                  -113                      -111.8
# 1571  15:14:53   9.8                  -113                       -97.7
# 1572  15:15:34   6.8                  -103                       -97.9
# 1573  15:15:11  10.2                   -95                       -97.7
#
#       Erro absoluto  Erro relativo        Lat        Lon  Distância(Km)  \
# 0              10.9      17.004680 -20.331911 -40.360861           0.03
# 1               2.3       3.727715 -20.331348 -40.360920           0.03
# 2               6.8      11.003236 -20.331340 -40.360920           0.03
# 3               4.0       6.349206 -20.331353 -40.360909           0.03
# 4               0.7       1.116427 -20.331354 -40.360909           0.03
# ...             ...            ...        ...        ...            ...
# 1569           15.9      15.603533 -20.321160 -40.332781           3.15
# 1570            1.2       1.073345 -20.319993 -40.333182           3.16
# 1571           15.3      15.660184 -20.320847 -40.332716           3.16
# 1572            5.1       5.209397 -20.320799 -40.332725           3.17
# 1573            2.7       2.763562 -20.320799 -40.332710           3.17
#
#       Unnamed: 9  ...            Unnamed: 11 Unnamed: 12  Unnamed: 13  \
# 0            NaN  ...                    NaN         NaN          NaN
# 1            NaN  ...  Perda urbana= 23,4 dB         NaN          NaN
# 2            NaN  ...                    NaN         NaN          NaN
# 3            NaN  ...                    NaN         NaN          NaN
# 4            NaN  ...                    NaN         NaN          NaN
# ...          ...  ...                    ...         ...          ...
# 1569         NaN  ...                    NaN         NaN          NaN
# 1570         NaN  ...                    NaN         NaN          NaN
# 1571         NaN  ...                    NaN         NaN          NaN
# 1572         NaN  ...                    NaN         NaN          NaN
# 1573         NaN  ...                    NaN         NaN          NaN
#
#       Unnamed: 14  Unnamed: 15  Unnamed: 16             Unnamed: 17  \
# 0             NaN          NaN          NaN                     NaN
# 1             NaN          NaN          NaN     Média erro absoluto
# 2             NaN          NaN          NaN                 10.0728
# 3             NaN          NaN          NaN  Media de erro relativo
# 4             NaN          NaN          NaN                 10.0315
# ...           ...          ...          ...                     ...
# 1569          NaN          NaN          NaN                     NaN
# 1570          NaN          NaN          NaN                     NaN
# 1571          NaN          NaN          NaN                     NaN
# 1572          NaN          NaN          NaN                     NaN
# 1573          NaN          NaN          NaN                     NaN
#
#      Unnamed: 18  Unnamed: 19  Unnamed: 20
# 0            NaN          NaN          NaN
# 1            NaN          NaN          NaN
# 2            NaN          NaN          NaN
# 3            NaN          NaN          NaN
# 4            NaN          NaN          NaN
# ...          ...          ...          ...
# 1569         NaN          NaN          NaN
# 1570         NaN          NaN          NaN
# 1571         NaN          NaN          NaN
# 1572         NaN          NaN          NaN
# 1573         NaN          NaN          NaN
#
# [1574 rows x 21 columns]

# %%
# Limpeza de coluna com valores nulos
limpo = xlsx.dropna(axis='columns')
limpo
# Out:
#          Horas   snr  Potencia medida(dBm)  Potencia Simulada-76%(dBm)  \
# 0     16:12:19  10.0                   -75                       -64.1
# 1     09:12:21   8.2                   -64                       -61.7
# 2     09:12:16   9.2                   -55                       -61.8
# 3     09:12:11   9.5                   -59                       -63.0
# 4     09:11:59  11.5                   -62                       -62.7
# ...        ...   ...                   ...                         ...
# 1569  15:14:44   8.8                   -86                      -101.9
# 1570  15:15:57   3.0                  -113                      -111.8
# 1571  15:14:53   9.8                  -113                       -97.7
# 1572  15:15:34   6.8                  -103                       -97.9
# 1573  15:15:11  10.2                   -95                       -97.7
#
#       Erro absoluto  Erro relativo        Lat        Lon  Distância(Km)
# 0              10.9      17.004680 -20.331911 -40.360861           0.03
# 1               2.3       3.727715 -20.331348 -40.360920           0.03
# 2               6.8      11.003236 -20.331340 -40.360920           0.03
# 3               4.0       6.349206 -20.331353 -40.360909           0.03
# 4               0.7       1.116427 -20.331354 -40.360909           0.03
# ...             ...            ...        ...        ...            ...
# 1569           15.9      15.603533 -20.321160 -40.332781           3.15
# 1570            1.2       1.073345 -20.319993 -40.333182           3.16
# 1571           15.3      15.660184 -20.320847 -40.332716           3.16
# 1572            5.1       5.209397 -20.320799 -40.332725           3.17
# 1573            2.7       2.763562 -20.320799 -40.332710           3.17
#
# [1574 rows x 9 columns]

# %%
# Reorganização dos dados pelo horário de ocorrência
limpo.reindex()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _ensure_has_len(seq)
#    5778     try:
# -> 5779         len(seq)
#    5780     except TypeError:
#
# TypeError: object of type 'int' has no len()
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-6c4ac508116a> in <module>
#       1 # Reorganização dos dados pelo horário de ocorrência
# ----> 2 limpo.reindex(columns=1)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     219         @wraps(func)
#     220         def wrapper(*args, **kwargs):
# --> 221             return func(*args, **kwargs)
#     222
#     223         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in reindex(self, *args, **kwargs)
#    3974         kwargs.pop("axis", None)
#    3975         kwargs.pop("labels", None)
# -> 3976         return super().reindex(**kwargs)
#    3977
#    3978     def drop(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4512         # perform the reindex on the axes
#    4513         return self._reindex_axes(
# -> 4514             axes, level, limit, tolerance, method, fill_value, copy
#    4515         ).__finalize__(self)
#    4516
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3856         if columns is not None:
#    3857             frame = frame._reindex_columns(
# -> 3858                 columns, method, copy, level, fill_value, limit, tolerance
#    3859             )
#    3860
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _reindex_columns(self, new_columns, method, copy, level, fill_value, limit, tolerance)
#    3898     ):
#    3899         new_columns, indexer = self.columns.reindex(
# -> 3900             new_columns, method=method, level=level, limit=limit, tolerance=tolerance
#    3901         )
#    3902         return self._reindex_with_indexers(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in reindex(self, target, method, level, limit, tolerance)
#    3383
#    3384         # GH7774: preserve dtype/tz if target is empty and not an Index.
# -> 3385         target = _ensure_has_len(target)  # target may be an iterator
#    3386
#    3387         if not isinstance(target, Index) and len(target) == 0:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _ensure_has_len(seq)
#    5779         len(seq)
#    5780     except TypeError:
# -> 5781         return list(seq)
#    5782     else:
#    5783         return seq
#
# TypeError: 'int' object is not iterable
