# %% [markdown]
# # Carga de Dados com Pandas

# %%
import numpy as np

# %%
import pandas as pd

# %%
# !type ex1.csv
# Out:
# ï»¿id, time, nodeaddr, appeui, gwaddr, modulation, datarate, snr, rssi, freq, lat, lon, alt, accuracy, hdop, sats, provider, name, user_agent
# 10135936, 2019-10-08 19:13:16, agro-pop2, lorawan_cpid3, 00800000A0003606, LORA, SF8BW125, 11.20, -55.00, 903.900, -20.331278, -40.360893, 39.8, 9.65, null, null, gps, lorawancpid10, null
# 10135931, 2019-10-08 19:13:08, agro-pop2, lorawan_cpid3, 00800000A0003606, LORA, SF7BW125, 9.50, -55.00, 904.500, -20.331273, -40.360889, 39.6, 8.58, null, null, gps, lorawancpid10, null
# 10135929, 2019-10-08 19:12:59, agro-pop2, lorawan_cpid3, 00800000A0003606, LORA, SF9BW125, 7.20, -57.00, 904.300, -20.331159, -40.360863, 36.4, 6.43, null, null, gps, lorawancpid10, null
# 10135928, 2019-10-08 19:12:55, agro-pop2, lorawan_cpid3, 00800000A0003606, LORA, SF8BW125, 11.20, -62.00, 903.900, -20.331002, -40.360719, 32.0, 4.29, null, null, gps, lorawancpid10, null
# ...

# %%
df=pd.read_csv('ex1.csv')

# %%
df
# Out:
#             id                  time    nodeaddr          appeui  \
# 0     10135936   2019-10-08 19:13:16   agro-pop2   lorawan_cpid3
# 1     10135931   2019-10-08 19:13:08   agro-pop2   lorawan_cpid3
# 2     10135929   2019-10-08 19:12:59   agro-pop2   lorawan_cpid3
# 3     10135928   2019-10-08 19:12:55   agro-pop2   lorawan_cpid3
# 4     10135925   2019-10-08 19:12:51   agro-pop2   lorawan_cpid3
# ...        ...                   ...         ...             ...
# 2579  10129817   2019-10-08 12:12:03   agro-pop2   lorawan_cpid3
# 2580  10129816   2019-10-08 12:11:59   agro-pop2   lorawan_cpid3
# 2581  10129813   2019-10-08 12:11:51   agro-pop2   lorawan_cpid3
# 2582  10129809   2019-10-08 12:11:46   agro-pop2   lorawan_cpid3
# 2583  10129806   2019-10-08 12:11:38   agro-pop2   lorawan_cpid3
#
#                  gwaddr  modulation   datarate   snr   rssi   freq        lat  \
# 0      00800000A0003606        LORA   SF8BW125  11.2  -55.0  903.9 -20.331278
# ...
